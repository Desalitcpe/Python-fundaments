# %% [markdown]
# <a href="https://colab.research.google.com/github/Desalitcpe/Python-fundaments/blob/main/Python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5>2:
  print("five is greater than two!")
# Out:
# five is greater than two!
# hello world

# %% [markdown]
# Python comment

# %%
#Ths is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Python Variable

# %%
x=1
z, b=0,-1
a, b, c=0,-1, 2

b="Sally" #This is a type of string

num_var=x, z, b, a, b, c
print(num_var)
# Out:
# (1, 0, 'Sally', 0, 'Sally', 2)
# Sally

# %%
b="sally" #this is a string
b=int(4)
print(b)  #it will display as an integer

b=float(4)
print(b) #it will display as an float or decimal
# Out:
# 4
# 4.0

# %% [markdown]
# type function

# %%
x=5
y="John"
print(type(x))
print(type(y))
#it will display the data types of the values stored in the variable
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Case sentitive

# %%
a=4
A="Sally"
#"a" will not overwrite "A"

# %% [markdown]
# Multiple variables

# %%
x,y,z="one","two","three"
print(x)
print(y)
print(z)

# %% [markdown]
# One Value to Mutiple Variables

# %%
x=y=z="four"
print(x)
print(y)
print(z)

# %% [markdown]
# Output Variables

# %%
#The pyton "print" is used to putput variables and "+" is used both text and variable
#example;

x="enjoying"
print("Python programming is " + x)
# Out:
# Python programming is enjoying

# %%
#other way

x="Python is "
y="enjoying"
z=x+y
print(z)
# Out:
# Python is enjoying

# %% [markdown]
# Arithmetic operations

# %%
a=10//3
print(a)

x=5
y=3
print(x+y)

b=5
c=3
sum=x+y
print(sum)

mdl=b%c

print(mdl)

sub=b-c

print(sub)

exp=b**c

print(exp)

dif=x/y

print(dif)

mul=x*y

print(mul)
# Out:
# 3
# 8
# 8
# 2
# 2
# 125
# 1.6666666666666667
# 15

# %% [markdown]
# Assignment operator

# %%
s = 1
s = 5
print(s)

s += 5
print(s)

s -= 5
print(s)

s *= 5
print(s)

s /= 5
print(s)

s %= 5
print(s)

s //= 5
print(s)

s **= 5
print(s)

s = int(s) # Convert s to an integer for bitwise operations due to certain difficulties
s &= 5
print(s)

s |= 5
print(s)

s ^= 5
print(s)

s >>= 5
print(s)

s <<= 5
print(s)
# Out:
# 5
# 10
# 5
# 25
# 5.0
# 0.0
# 0.0
# 0.0
# 0
# 5
# 0
# 0
# 0

# %% [markdown]
# Comparison Operators

# %%
s = 1
s == 5
print(bool(s))


s != 5
print(bool(s))


s > 5
print(bool(s))


s < 5
print(bool(s))

s >= 5
print(bool(s))

s <= 5
print(bool(s))
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# Logical Opertors

# %%
g=7

g > 5 and g < 10
print(bool(g))

g > 5 or g < 4
print(bool(g))

not(g > 5 and g < 10)
print(bool(g))

g > 5 == g < 15
print(bool(g))

s > 5 != g < 15
print(bool(g))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# Bitwise operators

# %%
var=3
print(var&1)
var=3
print(var|1)
var=3
print(var^1)
var=3
print(~var)
var=3
print(var>>1)
var=3
print(var<<1)
# Out:
# 1
# 3
# 2
# -4
# 1
# 6
